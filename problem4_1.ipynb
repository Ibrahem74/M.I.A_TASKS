# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv("Weather Dataset.csv")
weather
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 3775  2006-08-11 02:00:00.000 +0200  Mostly Cloudy        rain
# 3776  2006-12-26 12:00:00.000 +0100  Partly Cloudy        rain
# 3777  2006-12-19 20:00:00.000 +0100       Overcast        rain
# 3778  2006-12-10 11:00:00.000 +0100  Partly Cloudy        rain
# 3779  2006-12-10 15:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.isnull() #no null values
# Out:
#       Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0              False    False        False            False
# 1              False    False        False            False
# 2              False    False        False            False
# 3              False    False        False            False
# 4              False    False        False            False
# ...              ...      ...          ...              ...
# 3775           False    False        False            False
# 3776           False    False        False            False
# 3777           False    False        False            False
# 3778           False    False        False            False
# 3779           False    False        False            False
#
#       Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                        False     False              False
# 1                        False     False              False
# 2                        False     False              False
# ...

# %%
weather.describe() # problem in temp humidity visibility loud cover (min value)
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      3780.000000               3780.000000  3780.000000
# mean          9.473088                  8.909559     0.280862
# std          33.839341                  9.863589    32.543577
# min       -2000.000000                -11.911111 -2000.000000
# 25%           2.102778                 -0.401389     0.710000
# 50%          10.250000                 10.269444     0.860000
# 75%          17.088889                 17.088889     0.930000
# max          32.638889                 35.494444     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count        3780.000000             3780.000000      3780.000000
# mean           10.067603              200.250529         8.279035
# std             6.029814               91.711950        32.992211
# min             0.000000                0.000000     -2000.000000
# 25%             5.296900              145.000000         5.264700
# ...

# %%
weather = weather[weather['Temperature (C)'] != -2000]
weather = weather[weather['Humidity'] != -2000] 
weather = weather[weather['Visibility (km)'] != -2000]
weather = weather[weather['Loud Cover'] != -2000]
weather.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      3776.000000               3776.000000  3776.000000
# mean         10.006646                  8.909987     0.810132
# std           8.733297                  9.862036     0.160817
# min          -8.594444                -11.911111     0.320000
# 25%           2.105556                 -0.395833     0.710000
# 50%          10.269444                 10.269444     0.860000
# 75%          17.088889                 17.088889     0.930000
# max          32.638889                 35.494444     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count        3776.000000             3776.000000      3776.000000      3776.0
# mean           10.066120              200.322034         8.808892         0.0
# std             6.025570               91.688272         4.576885         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
weather.duplicated() #there are duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3775     True
# 3776     True
# 3777     True
# 3778     True
# 3779     True
# Length: 3776, dtype: bool

# %%
weather[weather['Formatted Date'].duplicated()==1] #showing duplicate data
# Out:
#                      Formatted Date        Summary Precip Type  \
# 2520  2006-02-11 14:00:00.000 +0100  Partly Cloudy        rain
# 2521  2006-12-26 21:00:00.000 +0100  Partly Cloudy        snow
# 2522  2006-08-13 08:00:00.000 +0200  Mostly Cloudy        rain
# 2523  2006-12-04 12:00:00.000 +0100  Mostly Cloudy        rain
# 2524  2006-04-07 01:00:00.000 +0200       Overcast        rain
# ...                             ...            ...         ...
# 3775  2006-08-11 02:00:00.000 +0200  Mostly Cloudy        rain
# 3776  2006-12-26 12:00:00.000 +0100  Partly Cloudy        rain
# 3777  2006-12-19 20:00:00.000 +0100       Overcast        rain
# 3778  2006-12-10 11:00:00.000 +0100  Partly Cloudy        rain
# 3779  2006-12-10 15:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 2520         0.116667                 -4.600000      0.85            16.9855
# ...

# %%
weather =weather.drop_duplicates()
weather.duplicated() # no duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2515    False
# 2516    False
# 2517    False
# 2518    False
# 2519    False
# Length: 2517, dtype: bool

# %%
weather=weather.drop(['Loud Cover'],axis=1) #not important zeros
weather
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2515  2006-02-20 19:00:00.000 +0100  Partly Cloudy        rain
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather.dtypes #all data types are correct
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
plt.figure(figsize=(14,7))
time = weather.index
temperature= weather['Temperature (C)']
plt.xlabel('Time')
plt.ylabel('Temprature')
plt.title("Temperature over time")
plt.xticks([])
plt.plot(time,temperature,color='purple')

# %%
plt.figure(figsize=(14,7))
plt.hist(temperature)
plt.ylabel('Temperature')
plt.xlabel('Time')
plt.xticks([])
# Out:
# ([], [])

# %%
plt.figure(figsize=(14,7))
humidity = weather['Humidity']
plt.scatter(humidity,temperature)
plt.ylabel('Temperature')
plt.xlabel('Humidity')
plt.title("Temprature over Humidity")
# Out:
# Text(0.5, 1.0, 'Temprature over Humidity')

# %%
corr = weather.select_dtypes(include=['int64','float64']).corr()
corr
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992993 -0.656982
# Apparent Temperature (C)         0.992993                  1.000000 -0.641375
# Humidity                        -0.656982                 -0.641375  1.000000
# Wind Speed (km/h)                0.122583                  0.057174 -0.303466
# Wind Bearing (degrees)           0.078901                  0.073904 -0.027316
# Visibility (km)                  0.572099                  0.563739 -0.467808
# Pressure (millibars)            -0.157498                 -0.158976  0.069610
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.122583                0.078901
# Apparent Temperature (C)           0.057174                0.073904
# Humidity                          -0.303466               -0.027316
# Wind Speed (km/h)                  1.000000                0.053524
# ...

# %%
plt.figure(figsize=(14,7))
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Correlation shows the relation ship between two variables

# %% [markdown]
# 1 if there is a perfect direct relationship between the two virables
# 0 if there isn't any relationship between the two virables
# -1 if there is a perfect inverse relationship between the two virables
